# %% [markdown]
# # AirBnB Madrid

# %% [markdown]
# # Data

# %% [markdown]
# Para realizar este proyecto contamos con el siguiente set de datos:
#
# | Fichero                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | airbnb_madrid_host.parquet       | Información del propietario de cada vivienda.                               |
# | airbnb_madrid_location.parquet   | Información de la localización de cada vivienda.                            |
# | airbnb_madrid_property.parquet   | Información de la vivienda.                                                 |
# | airbnb_madrid_conditions.parquet | Información de las condiciones de cada vivienda para poder alquilarla.      |
# | airbnb_madrid_reviews.parquet    | Información de las reseñas de cada vivienda.                                |

# %% [markdown]
# Y en cada set de datos se cuenta con las siguientes variables:

# %% [markdown]
# airbnb_madrid_host.parquet
#
# | Columna                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | id                               | Identificador único de la publicación en Airbnb.                            |
# | host_response_time               | Tiempo que tarda el anfitrión en responder a las consultas.                 |
# | host_response_rate               | Tasa de respuesta del anfitrión.                                            |
# | host_is_superhost                | Indica si el anfitrión es un "superhost" o no.                              |
# | host_has_profile_pic             | Indica si el anfitrión tiene una foto de perfil en su cuenta.               |
# | host_identity_verified           | Indica si la identidad del anfitrión ha sido verificada por Airbnb.         |
# | host_seniority                   | Antigüedad del anfitrión como miembro de Airbnb.                            |
# | host_verifications_email         | Indica si el anfitrión ha verificado su correo electrónico.                 |
# | host_verifications_phone         | Indica si el anfitrión ha verificado su número de teléfono.                 |
# | host_verifications_reviews       | Indica si el anfitrión ha verificado a través de reseñas de otros huéspedes.|
# | host_verifications_facebook      | Indica si el anfitrión ha verificado su cuenta de Facebook.                 |
# | calculated_host_listings_count   | Número de propiedades que el anfitrión tiene en Airbnb.                     |
# | host_verifications_government_id | Indica si el anfitrión ha verificado su identificación gubernamental.       |
#
# airbnb_madrid_location.parquet
#
# | Columna                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | id                               | Identificador único de la publicación en Airbnb.                            |
# | neighbourhood                    | Barrio donde se encuentra la propiedad.                                     |
# | neighbourhood_group              | Grupo de barrios al que pertenece el barrio.                                |
# | latitude                         | Latitud de la ubicación de la propiedad.                                    |
# | longitude                        | Longitud de la ubicación de la propiedad.                                   |
# | dist_km_sol                      | Distancia en kilómetros desde la propiedad hasta Puerta del Sol.           |
# | dist_km_airport                  | Distancia en kilómetros desde la propiedad hasta el aeropuerto.             |
#
# airbnb_madrid_property.parquet
#
# | Columna                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | id                               | Identificador único de la publicación en Airbnb.                            |
# | property_type                    | Tipo de propiedad (casa, apartamento, etc.).                                |
# | room_type                        | Tipo de habitación (compartida, privada, etc.).                             |
# | accommodates                     | Número máximo de huéspedes que pueden alojarse en la propiedad.             |
# | bathrooms                        | Número de baños en la propiedad.                                            |
# | bedrooms                         | Número de dormitorios en la propiedad.                                      |
# | beds                             | Número de camas en la propiedad.                                            |
# | bed_type                         | Tipo de cama (individual, doble, etc.).                                     |
# | amenities_wifi_internet          | Indica si la propiedad ofrece wifi o internet como amenidad.                |
# | amenities_tv                     | Indica si la propiedad ofrece televisión como amenidad.                     |
# | amenities_air_conditioning       | Indica si la propiedad ofrece aire acondicionado como amenidad.             |
# | amenities_heating                | Indica si la propiedad ofrece calefacción como amenidad.                    |
# | amenities_kitchen                | Indica si la propiedad ofrece cocina como amenidad.                         |
#
# airbnb_madrid_conditions.parquet
#
# | Columna                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | id                               | Identificador único de la publicación en Airbnb.                            |
# | price                            | Precio de alquiler por noche de la propiedad.                               |
# | minimum_nights                   | Mínimo de noches requeridas para reservar la propiedad.                     |
# | maximum_nights                   | Máximo de noches permitidas para reservar la propiedad.                     |
# | cancellation_policy              | Política de cancelación de reservas de la propiedad.                        |
# | require_guest_profile_picture    | Indica si se requiere foto de perfil de los huéspedes.                      |
# | require_guest_phone_verification | Indica si se requiere verificación telefónica de los huéspedes.             |
#
# airbnb_madrid_reviews.parquet
#
# | Columna                          | Descripción                                                                 |
# |----------------------------------|-----------------------------------------------------------------------------|
# | id                               | Identificador único de la publicación en Airbnb.                            |
# | number_of_reviews                | Número total de reseñas recibidas para la propiedad.                        |
# | number_of_reviews_ltm            | Número de reseñas recibidas en el último año.                               |
# | review_scores_rating             | Puntuación general de reseñas de la propiedad.                              |
# | review_scores_accuracy           | Puntuación de precisión en las reseñas de la propiedad.                     |
# | review_scores_cleanliness        | Puntuación de limpieza en las reseñas de la propiedad.                      |
# | review_scores_checkin            | Puntuación de check-in en las reseñas de la propiedad.                      |
# | review_scores_communication      | Puntuación de comunicación en las reseñas de la propiedad.                  |
# | review_scores_location           | Puntuación de ubicación en las reseñas de la propiedad.                     |
# | review_scores_value              | Puntuación de valor en las reseñas de la propiedad.                         |
# | reviews_per_month                | Número promedio de reseñas por mes para la propiedad.                       |
# | days_since_last_review           | Días transcurridos desde la última reseña recibida para la propiedad.       |
# | days_since_first_review          | Días transcurridos desde la primera reseña recibida para la propiedad.      |
# | number_of_reviews_en             | Número de reseñas en inglés recibidas para la propiedad.                    |
# | number_of_reviews_es             | Número de reseñas en español recibidas para la propiedad.                   |
# | number_of_reviews_otros          | Número de reseñas en otros idiomas recibidas para la propiedad.             |

# %%
import sys
sys.path.append('./utils')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from MiguelTK import *

# %%
df_host = pd.read_parquet('data/airbnb_madrid_host.parquet')
df_location = pd.read_parquet('data/airbnb_madrid_location.parquet')
df_property = pd.read_parquet('data/airbnb_madrid_property.parquet')
df_conditions = pd.read_parquet('data/airbnb_madrid_conditions.parquet')
df_reviews = pd.read_parquet('data/airbnb_madrid_reviews.parquet')

# %%
df = df_conditions.set_index('id').join(
    [
        df_host.drop(columns='id'),
        df_location.drop(columns='id'),
        df_property.drop(columns='id'),
        df_reviews.drop(columns='id')
    ],
)

# %%
del df_host, df_location, df_property, df_conditions, df_reviews

# %%
df = df.query('property_type == "apartment"')

# %% [markdown]
# # Contexto del problema

# %% [markdown]
# El cliente quiere saber de qué manera puede optimizar los alquileres de las propiedades que tiene en Madrid publicadas en la plataforma AirBnB

# %%
len(df)
# Out:
# 17180

# %%
sns.histplot(
    x = 'price',
    data = df.query('price < price.quantile(.9)'),
    bins = 50,
    color = '#004aad'
)
plt.axvline(df.price.median(),color='red')
plt.title('Distribución de precios')
# Out:
# Text(0.5, 1.0, 'Distribución de precios')

# %%
print(df.price.quantile(.9))
df = df.query('price < price.quantile(.9)')
# Out:
# 195.0

# %%
df['price_per_visitor'] = df.price / df.accommodates

# %%
sns.histplot(
    x = 'price_per_visitor',
    data = df,
    bins = 50,
    color = '#004aad'
)
plt.xlim((0,75))
plt.axvline(df.price_per_visitor.median(),color='red')
plt.title('Distribución de precios por persona')
# Out:
# Text(0.5, 1.0, 'Distribución de precios por persona')

# %%
df.price.median()
# Out:
# 60.0

# %%
df.price_per_visitor.median()
# Out:
# 20.0

# %%
df.price_per_visitor.quantile(.25)
# Out:
# 15.0

# %%
df.price_per_visitor.quantile(.75)
# Out:
# 27.5

# %% [markdown]
# # Problema

# %% [markdown]
# "¿Qué parte de una publicación de AirBnB (condiciones de la propiedad y el alquiler, reseñas previas y localización) tiene mayor impacto en los precios de los alquileres de apartamentos en Madrid?"

# %% [markdown]
# # Roadmap

# %% [markdown]
# Se han planteado cuatro hipótesis. Se va a analizar si en los precios de los alquileres tiene mayor impacto:
# - **condiciones de la propiedad y el alquiler**
# - **Reseñas previas**
# - **La localización**

# %% [markdown]
# # Insights

# %% [markdown]
# ## Las condiciones de la propiedad y el alquiler

# %% [markdown]
# ### Impacto de las prestaciones del apartamento

# %%
amenities =[
            'amenities_wifi_internet',
            'amenities_tv',
            'amenities_air_conditioning',
            'amenities_heating',
            'amenities_kitchen'
            ]
i = 1
for am in amenities:
    plt.subplot(2,3,i)
    i += 1
    sns.boxplot(
        x = am,
        hue = am,
        legend = False,
        y = 'price',
        data = df,
        palette = palette
    )
    plt.xlabel(am[10:])
plt.suptitle('Amenities and prices')
subplots_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2404142317.py:12: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2404142317.py:12: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2404142317.py:12: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2404142317.py:12: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2404142317.py:12: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(

# %%
i = 1
for am in amenities:
    plt.subplot(2,3,i)
    i += 1
    sns.boxplot(
        x = am,
        hue = am,
        legend = False,
        y = 'price_per_visitor',
        data = df.query('price_per_visitor < 50'),
        palette = palette
    )
    plt.xlabel(am[10:])
plt.suptitle('Amenities and prices')
subplots_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3914906195.py:5: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3914906195.py:5: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3914906195.py:5: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3914906195.py:5: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3914906195.py:5: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(

# %%
var = 'price'
plt.figure(figsize=(10,5))
df_ = (
    df
    [[var] + amenities]
    .melt(var)
)
sns.boxplot(
    x = 'variable',
    hue = 'value',
    legend = True,
    y = var,
    data = df_,
    palette = palette,
)
plt.axhline(df[var].median(),color = 'red', ls = '--', label = 'mediana')
plt.xticks(range(5),[tick.replace('_','\n') for tick in df_.variable.unique()])
plt.legend(loc='upper left')
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1226635805.py:8: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(

# %%
var = 'price_per_visitor'
plt.figure(figsize=(10,5))
df_ = (
    df
    [[var] + amenities]
    .melt(var)
)
sns.boxplot(
    x = 'variable',
    hue = 'value',
    legend = True,
    y = var,
    data = df_,
    palette = palette
)
plt.axhline(df[var].median(),color = 'red', ls = '--', label = 'mediana')
plt.legend(loc='upper left')
plt.xticks(range(5),[tick.replace('_','\n') for tick in df_.variable.unique()])
plt.ylim((0,50))
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2129237556.py:8: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.boxplot(

# %% [markdown]
# ### Impacto del número de huéspedes, y huéspedes por habitación

# %%
df['accommodates_cat'] = pd.cut(
    df.accommodates,
    [0,1,3,10,16],
    labels = ['solo 1','2 o 3','entre 4 y 10','más de 10']
)

# %%
sns.violinplot(
    x = 'accommodates_cat',
    y = 'price',
    data = df,
    palette = palette
)
plt.title('Número de huéspedes y precio')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1294076668.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1294076668.py:1: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.violinplot(
# Text(0.5, 1.0, 'Número de huéspedes y precio')

# %%
sns.violinplot(
    x = 'accommodates_cat',
    y = 'price_per_visitor',
    data = df.query('price_per_visitor < 75'),
    palette = palette
)
plt.title('Número de huéspedes y precio')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\4159348684.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\4159348684.py:1: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.violinplot(
# Text(0.5, 1.0, 'Número de huéspedes y precio')

# %%
df['acc_per_room'] = pd.cut(df['accommodates'] / df['bedrooms'],[0,1,2,3,8],labels=['una','una o dos','dos o tres','más de tres'])
sns.boxplot(
    x = 'acc_per_room',
    y = 'price',
    data = df,
    palette = palette
)
plt.title('Impacto del número medio de huéspedes por habitación en el precio')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\902404825.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\902404825.py:2: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.boxplot(
# Text(0.5, 1.0, 'Impacto del número medio de huéspedes por habitación en el precio')

# %%
df['acc_per_room'] = pd.cut(df['accommodates'] / df['bedrooms'],[0,1,2,3,8],labels=['una','una o dos','dos o tres','más de tres'])
sns.boxplot(
    x = 'acc_per_room',
    y = 'price_per_visitor',
    data = df,
    palette = palette
)
plt.ylim((0,60))
plt.title('Impacto del número medio de huéspedes por habitación en el precio')
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1609641046.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1609641046.py:2: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.boxplot(
# Text(0.5, 1.0, 'Impacto del número medio de huéspedes por habitación en el precio')

# %% [markdown]
# ### Impacto de las condiciones del alquiler

# %%
df['minimum_nights_cat'] = pd.cut(
    df.minimum_nights,
    [0,1,7,30,df.minimum_nights.max()],
    labels=['un día','de un día a una semana','de una semana a un mes','más de un mes']
)
sns.boxplot(
    x = 'minimum_nights_cat',
    hue = 'minimum_nights_cat',
    legend = False,
    y = 'price',
    palette = palette,
    data = df
)
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3791611982.py:6: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.boxplot(

# %%
df['maximum_nights_cat'] = pd.cut(
    df.maximum_nights,
    [0,1,7,30,df.maximum_nights.max()],
    labels=['un día','de un día a una semana','de una semana a un mes','más de un mes']
)
sns.boxplot(
    x = 'maximum_nights_cat',
    hue = 'maximum_nights_cat',
    legend = False,
    y = 'price',
    palette = palette,
    data = df
)
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\818470470.py:6: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.boxplot(

# %% [markdown]
# ## Reseñas previas

# %%
reviews = [
    'review_scores_accuracy', 'review_scores_cleanliness',
    'review_scores_checkin', 'review_scores_communication',
    'review_scores_location', 'review_scores_value'
]

# %%
i = 1
for rev in reviews:
    df[f'{rev}_cat'] = pd.cut(df[rev],3,labels=['mala','regular','buena'])
    plt.subplot(2,3,i)
    i += 1
    sns.boxplot(
        data = df,
        x = f'{rev}_cat',
        hue = f'{rev}_cat',
        legend = False,
        y = 'price',
        palette = palette
    )
    plt.xlabel(rev[14:])
    plt.xticks(rotation=30)
plt.suptitle('Reviews')
subplots_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\328726592.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(

# %%
i = 1
for rev in reviews:
    df[f'{rev}_cat'] = pd.cut(df[rev],3,labels=['mala','regular','buena'])
    plt.subplot(2,3,i)
    i += 1
    sns.boxplot(
        data = df,
        x = f'{rev}_cat',
        hue = f'{rev}_cat',
        legend = False,
        y = 'price_per_visitor',
        palette = palette
    )
    plt.xlabel(rev[14:])
    plt.xticks(rotation=30)
    plt.ylim([0,50])
plt.suptitle('Reviews')
subplots_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\2465535743.py:6: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.boxplot(

# %%
reviews += ['review_scores_rating']

# %%
corr = (
    df
    .groupby('accommodates_cat')
    [['price_per_visitor']+reviews]
    .corr(method="spearman")
    .reset_index(names=["group", "feature"])
    .query('feature == "price_per_visitor"')
    .drop(columns=['feature','price_per_visitor'])
    .set_index('group')
)
sns.heatmap(
    corr.T,
    annot=True,
    cmap=cmap,
    fmt=".2f",
    linewidths=.5,
    vmin = -.3,
    vmax  =.3,
    yticklabels=[tick[14:] for tick in corr.columns]
)
plt.title('Correlacion de precios por persona con las reseñas')
plt.show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\617395338.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('accommodates_cat')

# %%
corr = (
    df
    .groupby('neighbourhood_group')
    [['price_per_visitor']+reviews]
    .corr(method="spearman")
    .reset_index(names=["group", "feature"])
    .query('feature == "price_per_visitor"')
    .drop(columns=['feature','price_per_visitor'])
    .set_index('group')
)
sns.heatmap(
    corr,
    annot=True,
    cmap=cmap,
    fmt=".2f",
    linewidths=.5,
    vmin = -.3,
    vmax  =.3,
    xticklabels=[tick[14:] for tick in corr.columns],
)
plt.title('Correlacion de precios por persona con las reseñas')
plt.show()

# %%
sns.boxplot(
    x = 'bed_type',
    y = 'price_per_visitor',
    data = df,
    hue = 'bed_type',
    legend = False,
    palette = palette
)
plt.title('Impacto del tipo de cama')
plt.ylim((0,50))
plt.show()

# %%
sns.boxplot(
    x = 'room_type',
    y = 'price',
    data = df,
    hue = 'bed_type',
    legend = True,
    palette = palette
)
plt.title('Impacto del tipo de cama y tipo de habitación')
# plt.ylim((0,50))
plt.show()

# %% [markdown]
# ## Impacto de la localización

# %%
df['group_med'] = df.groupby('neighbourhood_group').price.transform('mean')
sns.boxplot(
    x = 'neighbourhood_group',
    hue = 'neighbourhood_group',
    legend = False,
    y = 'price',
    data = df.sort_values('group_med'),
    palette = palette
)
rot_show()
df_ = (
    df
    .groupby('neighbourhood_group')
    .price
    .mean()
    .reset_index()
)
sns.barplot(
    x = 'neighbourhood_group',
    hue = 'neighbourhood_group',
    y = 'price',
    data = df_.sort_values('price'),
    errorbar = 'sd',
    **kwargs
)
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_15236\678906467.py:2: UserWarning:
# The palette list has fewer values (5) than needed (21) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(
# C:\Users\micha\AppData\Local\Temp\ipykernel_15236\678906467.py:18: UserWarning:
# The palette list has fewer values (5) than needed (21) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %%
df_ = (
    df
    .groupby('neighbourhood_group')
    .price_per_visitor
    .mean()
    .reset_index()
)
sns.barplot(
    x = 'neighbourhood_group',
    hue = 'neighbourhood_group',
    y = 'price_per_visitor',
    data = df_.sort_values('price_per_visitor'),
    errorbar = 'sd',
    **kwargs
)
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_15236\1438115993.py:8: UserWarning:
# The palette list has fewer values (5) than needed (21) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(

# %%
corr = (
    df
    .groupby('accommodates_cat')
    [['price_per_visitor','dist_km_sol','dist_km_airport']]
    .corr(method="spearman")
    .reset_index(names=["group", "feature"])
    .query('feature == "price_per_visitor"')
    .drop(columns=['feature','price_per_visitor'])
    .set_index('group')
)
sns.heatmap(
    corr,
    annot=True,
    cmap=cmap,
    fmt=".2f",
    linewidths=.5,
    vmin = -.3,
    vmax  =.3
)
plt.title('Correlacion de precios por persona con la ubicación')
plt.show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\73840168.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('accommodates_cat')

# %%
df_ = (
    df
    .groupby(['neighbourhood_group','accommodates_cat'],as_index=False)
    .size()
)
df_ = (   
    df_
    .groupby('neighbourhood_group')
    ['size']
    .apply(lambda x: x / x.sum())
    .reset_index()
    .drop(columns='level_1')
    .assign(accommodates_cat = df_['accommodates_cat'])
    .rename(columns={'size':'percentage'})
)
plt.figure(figsize=(15,5))
sns.barplot(
    data = df_,
    x = 'neighbourhood_group',
    y = 'percentage',
    hue = 'accommodates_cat',
    palette = palette,
    edgecolor = 'black',
    linewidth = 1,
    legend = True
)
plt.title('Número de huéspedes por zona')
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3786051834.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['neighbourhood_group','accommodates_cat'],as_index=False)
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\3786051834.py:17: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.barplot(

# %%
df_ = (
    df
    .groupby(['neighbourhood_group','room_type'],as_index=False)
    .size()
)
df_ = (   
    df_
    .groupby('neighbourhood_group')
    ['size']
    .apply(lambda x: x / x.sum())
    .reset_index()
    .drop(columns='level_1')
    .assign(room_type = df_['room_type'])
    .rename(columns={'size':'percentage'})
)
plt.figure(figsize=(15,5))
sns.barplot(
    data = df_,
    x = 'neighbourhood_group',
    y = 'percentage',
    hue = 'room_type',
    palette = palette,
    edgecolor = 'black',
    linewidth = 1,
    legend = True
)
plt.title('Tipo de habitación por zona')
rot_show()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16104\1351544441.py:17: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %%
plt.stackplot(
    
)
